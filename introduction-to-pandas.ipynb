# %%
import numpy

# %%
import string

# %%
import pandas as pd

# %%
print("ja sam idiot")
# Out:
# ja sam idiot

# %%
l=[1,2,3]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# #2 main datatyper
# series = pd.Series("BMW","Toyota","Honda")

# %%
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red","Blue","white"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    white
# dtype: object

# %% [markdown]
# # 1-dimensional

# %% [markdown]
# #DataFrame = 2-dimensional

# %%
car_data= pd.DataFrame({"car make":series,"Colour":colours})
car_data
# Out:
#   car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  white

# %% [markdown]
# #Import data
#
#  print(cra-sales)

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
for i in car_sales:
    print(i)
# Out:
# Make
# Colour
# Odometer (KM)
# Doors
# Price

# %%
#EXPORTING data frame
car_sales.to_csv("exported-car-sales.csv",index=False)

# %%
exporte_car_sales = pd.read_csv("exported-car-sales.csv")
exporte_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
#Atribute
car_sales.dtypes
#Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
 car_sales.mean()
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_2668\2804144511.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([300,1500,11250])
car_prices.mean()
# Out:
# 4350.0

# %%
car_prices = pd.Series([car_sales.index[5]])
car_prices.mean()
# Out:
# 5.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Price"].sum()
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# # viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# # .loc & .iloc

# %%
animals= pd.Series(["cat","dog","bird","pandas","snake"], index=[0,3,9,8,3])
animals
# Out:
# 0       cat
# 3       dog
# 9      bird
# 8    pandas
# 3     snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# # .iloc

# %%
animals.iloc[3]
# Out:
# 'pandas'

# %% [markdown]
# # refers to position and loc refers on index!!!

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals
# Out:
# 0       cat
# 3       dog
# 9      bird
# 8    pandas
# 3     snake
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Goupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"] = car_sales["Price"].replace('[\$\,]', '', regex=True).astype(float)

# %%
car_sales["Price"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_mising= pd.read_csv("car-sales-missing-data.csv")
car_sales_mising
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_mising['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_sales_mising["Odometer"].fillna(car_sales_mising['Odometer'].mean(), inplace = True)

# %%
car_sales_mising
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_mising.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_mising
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_mising.dropna(inplace=True)

# %%
car_sales_mising
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_mising= pd.read_csv("car-sales-missing-data.csv")
car_sales_mising
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_m_dropped = car_sales_mising.dropna()
car_sales_m_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_m_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
#column from series
seats_column = pd.Series([5,5,5,5,5])
#New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
# Column from Python list
fuel_economy = [7.5,9.2,5.0,9.6,8.7,4.7,7.6,3.0,4.5,2.9]
car_sales["Fuel per (KM)"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9

# %%
car_sales["Total fuel used (L)"]=car_sales["Odometer (KM)"]/100*car_sales["Fuel per (KM)"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9
#
#    Total duel used  Total fuel used  Total fuel used (L)
# 0        11253.225        11253.225            11253.225
# 1         8086.708         8086.708             8086.708
# ...

# %%
# Create a column from single value

car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9
#
#    Total duel used  Total fuel used  Total fuel used (L)  Number of wheels
# 0        11253.225        11253.225            11253.225                 4
# ...

# %%
car_sales['Passed road safety']=True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9
#
#    Total duel used  Total fuel used  Total fuel used (L)  Number of wheels  \
# 0        11253.225        11253.225            11253.225                 4
# ...

# %%
car_sales=car_sales.drop("Total fuel used", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [116], in <cell line: 1>()
# ----> 1 car_sales=car_sales.drop("Total fuel used", axis=1)
#
# File ~\Desktop\sample_project_1\env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Desktop\sample_project_1\env\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9
#
#    Total duel used  Total fuel used (L)  Number of wheels  Passed road afety  \
# 0        11253.225            11253.225                 4               True
# ...

# %%
car_sales= car_sales=car_sales.drop("Total duel used", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9
#
#    Total fuel used (L)  Number of wheels  Passed road afety  \
# 0            11253.225                 4               True
# 1             8086.708                 4               True
# ...

# %%
vlasnici = ["Ljubo","Pero","Ivo", "Maro","Garo","Ljubo","Pero","Ivo", "Maro","Garo"]
car_sales["Owners"]= vlasnici

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9
#
#    Total fuel used (L)  Number of wheels  Passed road afety  \
# 0            11253.225                 4               True
# 1             8086.708                 4               True
# ...

# %%
car_sales_shuffeld=car_sales.sample(frac=1)

# %%
car_sales_shuffeld
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 9  nissan  White          31600      4   9700.0    5.0            2.9
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
#
#    Total fuel used (L)  Number of wheels  Passed road afety  \
# 4            18539.265                 4               True
# 3             1073.184                 4               True
# ...

# %%
#Samo 20 posto podataka
car_sales_shuffeld.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per (KM)  \
# 4  nissan  White         213095      4  3500.0    5.0            8.7
# 8  toyota  White          60000      4  6250.0    5.0            4.5
#
#    Total fuel used (L)  Number of wheels  Passed road afety  \
# 4            18539.265                 4               True
# 8             2700.000                 4               True
#
#    Passed road safety Owners
# 4                True   Garo
# 8                True   Maro

# %%
car_sales_shuffeld.reset_index(drop= True,inplace=True)

# %%
car_sales_shuffeld
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  nissan  White         213095      4   3500.0    5.0            8.7
# 1     bmw  Black          11179      5  22000.0    5.0            9.6
# 2  nissan  White          31600      4   9700.0    5.0            2.9
# 3  toyota  White         150043      4   4000.0    5.0            7.5
# 4   honda   Blue          45698      4   7500.0    5.0            7.6
# 5   honda   Blue          54738      4   7000.0    5.0            3.0
# 6  toyota  White          60000      4   6250.0    5.0            4.5
# 7   honda    Red          87899      4   5000.0    5.0            9.2
# 8  toyota  Green          99213      4   4500.0    5.0            4.7
# 9  toyota   Blue          32549      3   7000.0    5.0            5.0
#
#    Total fuel used (L)  Number of wheels  Passed road afety  \
# 0            18539.265                 4               True
# 1             1073.184                 4               True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    5.0            9.2
# 2  toyota   Blue          32549      3   7000.0    5.0            5.0
# 3     bmw  Black          11179      5  22000.0    5.0            9.6
# 4  nissan  White         213095      4   3500.0    5.0            8.7
# 5  toyota  Green          99213      4   4500.0    5.0            4.7
# 6   honda   Blue          45698      4   7500.0    5.0            7.6
# 7   honda   Blue          54738      4   7000.0    5.0            3.0
# 8  toyota  White          60000      4   6250.0    5.0            4.5
# 9  nissan  White          31600      4   9700.0    5.0            2.9
#
#    Total fuel used (L)  Number of wheels  Passed road afety  \
# 0            11253.225                 4               True
# 1             8086.708                 4               True
# ...

# %%
car_sales["Odometer (MPH)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per (KM)  \
# 0  toyota  White      93776.875      4   4000.0    5.0            7.5
# 1   honda    Red      54936.875      4   5000.0    5.0            9.2
# 2  toyota   Blue      20343.125      3   7000.0    5.0            5.0
# 3     bmw  Black       6986.875      5  22000.0    5.0            9.6
# 4  nissan  White     133184.375      4   3500.0    5.0            8.7
# 5  toyota  Green      62008.125      4   4500.0    5.0            4.7
# 6   honda   Blue      28561.250      4   7500.0    5.0            7.6
# 7   honda   Blue      34211.250      4   7000.0    5.0            3.0
# 8  toyota  White      37500.000      4   6250.0    5.0            4.5
# 9  nissan  White      19750.000      4   9700.0    5.0            2.9
#
#    Total fuel used (L)  Number of wheels  Passed road afety  \
# 0            11253.225                 4               True
# 1             8086.708                 4               True
# ...
